# %%
import pandas as pd
import numpy as np

from ml_from_scratch.ensemble import RandomForestClassifier

from ml_from_scratch.cross_validation import GridSearchCV
from ml_from_scratch.metrics import precision_score

from sklearn.model_selection import train_test_split

# %%
pd.set_option('max_colwidth', 400)

# %%
# Import data
filename = "data/churn.csv"

# Load
data = pd.read_csv(filename, sep=',')
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
# Drop unnecessary Data
data = data.drop(columns=["RowNumber", "CustomerId", "Surname", "Geography"])

# Transform Gender Data
data["Gender"] = data["Gender"].apply(lambda x: 1 if x == "Female" else 0)

data.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619       1   42       2       0.00              1          1
# 1          608       1   41       1   83807.86              1          0
# 2          502       1   42       8  159660.80              3          1
# 3          699       1   39       1       0.00              2          0
# 4          850       1   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88       1
# 1               1        112542.58       0
# 2               0        113931.57       1
# 3               0         93826.63       0
# 4               1         79084.10       0

# %%
data["Exited"].value_counts(normalize=True)
# Out:
# Exited
# 0    0.7963
# 1    0.2037
# Name: proportion, dtype: float64

# %%
target_columns = "Exited"
X = data.drop(columns=target_columns)
y = data[target_columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.25,
                                                    stratify=y)

# %%
grid_params = {
    "n_estimators": [10, 50, 200, 500, 800, 1000],
    "max_features": ["sqrt", "log2"],
    "criterion": ["gini", "entropy"]
}

# %%
clf = GridSearchCV(estimator=RandomForestClassifier,
                      param_grid=grid_params,
                      scoring="accuracy",
                      cv=10)

# %%
clf.fit(X=X_train, y=y_train)
# Out:
#                                                                  parameter  \
# 0        {'n_estimators': 10, 'max_features': 'sqrt', 'criterion': 'gini'}
# 1     {'n_estimators': 10, 'max_features': 'sqrt', 'criterion': 'entropy'}
# 2        {'n_estimators': 10, 'max_features': 'log2', 'criterion': 'gini'}
# 3     {'n_estimators': 10, 'max_features': 'log2', 'criterion': 'entropy'}
# 4        {'n_estimators': 50, 'max_features': 'sqrt', 'criterion': 'gini'}
# 5     {'n_estimators': 50, 'max_features': 'sqrt', 'criterion': 'entropy'}
# 6        {'n_estimators': 50, 'max_features': 'log2', 'criterion': 'gini'}
# 7     {'n_estimators': 50, 'max_features': 'log2', 'criterion': 'entropy'}
# 8       {'n_estimators': 200, 'max_features': 'sqrt', 'criterion': 'gini'}
# 9    {'n_estimators': 200, 'max_features': 'sqrt', 'criterion': 'entropy'}
# 10      {'n_estimators': 200, 'max_features': 'log2', 'criterion': 'gini'}
# 11   {'n_estimators': 200, 'max_features': 'log2', 'criterion': 'entropy'}
# 12      {'n_estimators': 500, 'max_features': 'sqrt', 'criterion': 'gini'}
# 13   {'n_estimators': 500, 'max_features': 'sqrt', 'criterion': 'entropy'}
# 14      {'n_estimators': 500, 'max_features': 'log2', 'criterion': 'gini'}
# 15   {'n_estimators': 500, 'max_features': 'log2', 'criterion': 'entropy'}
# 16      {'n_estimators': 800, 'max_features': 'sqrt', 'criterion': 'gini'}
# 17   {'n_estimators': 800, 'max_features': 'sqrt', 'criterion': 'entropy'}
# 18      {'n_estimators': 800, 'max_features': 'log2', 'criterion': 'gini'}
# 19   {'n_estimators': 800, 'max_features': 'log2', 'criterion': 'entropy'}
# 20     {'n_estimators': 1000, 'max_features': 'sqrt', 'criterion': 'gini'}
# 21  {'n_estimators': 1000, 'max_features': 'sqrt', 'criterion': 'entropy'}
# 22     {'n_estimators': 1000, 'max_features': 'log2', 'criterion': 'gini'}
# 23  {'n_estimators': 1000, 'max_features': 'log2', 'criterion': 'entropy'}
#
#    score_method  cv_score_train  cv_score_valid
# 0      accuracy        0.873793        0.807733
# 1      accuracy        0.875719        0.808400
# 2      accuracy        0.873793        0.807733
# 3      accuracy        0.875719        0.808400
# 4      accuracy        0.873985        0.806533
# 5      accuracy        0.877230        0.805733
# 6      accuracy        0.873985        0.806533
# 7      accuracy        0.877230        0.805733
# 8      accuracy        0.858296        0.804000
# 9      accuracy        0.860785        0.804133
# 10     accuracy        0.858296        0.804000
# 11     accuracy        0.860785        0.804133
# 12     accuracy        0.855170        0.802667
# 13     accuracy        0.857407        0.803067
# 14     accuracy        0.855170        0.802667
# 15     accuracy        0.857407        0.803067
# 16     accuracy        0.858504        0.803067
# 17     accuracy        0.860519        0.803333
# 18     accuracy        0.858504        0.803067
# 19     accuracy        0.860519        0.803333
# 20     accuracy        0.856815        0.802667
# 21     accuracy        0.858711        0.803200
# 22     accuracy        0.856815        0.802667
# 23     accuracy        0.858711        0.803200

# %%
clf.cv_results[11]["cv_score_valid"]
# Out:
# 0.8041333333333334

# %%
clf._parameters[11]
# Out:
# {'n_estimators': 200, 'max_features': 'log2', 'criterion': 'entropy'}

# %%
cv_precision = GridSearchCV(estimator=RandomForestClassifier,
                            param_grid=grid_params,
                            scoring="precision",
                            cv=10)

# %%
cv_precision.fit(X_train, y_train)
# Out:
#                                                                  parameter  \
# 0        {'n_estimators': 10, 'max_features': 'sqrt', 'criterion': 'gini'}
# 1     {'n_estimators': 10, 'max_features': 'sqrt', 'criterion': 'entropy'}
# 2        {'n_estimators': 10, 'max_features': 'log2', 'criterion': 'gini'}
# 3     {'n_estimators': 10, 'max_features': 'log2', 'criterion': 'entropy'}
# 4        {'n_estimators': 50, 'max_features': 'sqrt', 'criterion': 'gini'}
# 5     {'n_estimators': 50, 'max_features': 'sqrt', 'criterion': 'entropy'}
# 6        {'n_estimators': 50, 'max_features': 'log2', 'criterion': 'gini'}
# 7     {'n_estimators': 50, 'max_features': 'log2', 'criterion': 'entropy'}
# 8       {'n_estimators': 200, 'max_features': 'sqrt', 'criterion': 'gini'}
# 9    {'n_estimators': 200, 'max_features': 'sqrt', 'criterion': 'entropy'}
# 10      {'n_estimators': 200, 'max_features': 'log2', 'criterion': 'gini'}
# 11   {'n_estimators': 200, 'max_features': 'log2', 'criterion': 'entropy'}
# 12      {'n_estimators': 500, 'max_features': 'sqrt', 'criterion': 'gini'}
# 13   {'n_estimators': 500, 'max_features': 'sqrt', 'criterion': 'entropy'}
# 14      {'n_estimators': 500, 'max_features': 'log2', 'criterion': 'gini'}
# 15   {'n_estimators': 500, 'max_features': 'log2', 'criterion': 'entropy'}
# 16      {'n_estimators': 800, 'max_features': 'sqrt', 'criterion': 'gini'}
# 17   {'n_estimators': 800, 'max_features': 'sqrt', 'criterion': 'entropy'}
# 18      {'n_estimators': 800, 'max_features': 'log2', 'criterion': 'gini'}
# 19   {'n_estimators': 800, 'max_features': 'log2', 'criterion': 'entropy'}
# 20     {'n_estimators': 1000, 'max_features': 'sqrt', 'criterion': 'gini'}
# 21  {'n_estimators': 1000, 'max_features': 'sqrt', 'criterion': 'entropy'}
# 22     {'n_estimators': 1000, 'max_features': 'log2', 'criterion': 'gini'}
# 23  {'n_estimators': 1000, 'max_features': 'log2', 'criterion': 'entropy'}
#
#    score_method  cv_score_train  cv_score_valid
# 0     precision        0.999241        0.825012
# 1     precision        0.998888        0.827338
# 2     precision        0.999241        0.825012
# 3     precision        0.998888        0.827338
# 4     precision        1.000000        0.974603
# 5     precision        1.000000        0.972222
# 6     precision        1.000000        0.974603
# 7     precision        1.000000        0.972222
# 8     precision        1.000000        1.000000
# 9     precision        1.000000        1.000000
# 10    precision        1.000000        1.000000
# 11    precision        1.000000        1.000000
# 12    precision        1.000000        1.000000
# 13    precision        1.000000        1.000000
# 14    precision        1.000000        1.000000
# 15    precision        1.000000        1.000000
# 16    precision        1.000000        1.000000
# 17    precision        1.000000        1.000000
# 18    precision        1.000000        1.000000
# 19    precision        1.000000        1.000000
# 20    precision        1.000000        1.000000
# 21    precision        1.000000        1.000000
# 22    precision        1.000000        1.000000
# 23    precision        1.000000        1.000000

# %%
cv_precision._parameters[6]
# Out:
# {'n_estimators': 50, 'max_features': 'log2', 'criterion': 'gini'}

# %%
cv_precision.cv_results[6]["cv_score_valid"]
# Out:
# 0.9746031746031747

# %%
rforest = RandomForestClassifier(n_estimators=50,
                                 max_features="log2",
                                 criterion="gini")

rforest.fit(X_train, y_train)
y_pred = rforest.predict(X_test)

precision_score(y_test, y_pred)
# Out:
# 0.9655172413793104

# %%
print("Precision Score: ", precision_score(y_test, y_pred))
# Out:
# Precision Score:  0.9655172413793104

# %%
rforest_acc = RandomForestClassifier(n_estimators=200,
                                 max_features="log2",
                                 criterion="entropy")

rforest_acc.fit(X_train, y_train)
y_pred_acc = rforest_acc.predict(X_test)

precision_score(y_test, y_pred_acc)
# Out:
# 1.0
